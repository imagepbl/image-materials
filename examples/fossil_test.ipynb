# %%
#make sure to set the scenario in drivers.py to your selected scenario (SSP2) is the only option right now. 
# set the scenario to the correct ones in the other pre-processing files as well (lifetime, materials, capacity) to ensure that the correct data is used for the model.

from pathlib import Path
import prism
import pandas as pd
import numpy as np
import xarray as xr
import scipy
import matplotlib.pyplot as plt
import warnings
import prism
import logging
import pickle

from imagematerials.model import GenericStocks, MaterialIntensities, GenericMaterials, SharesInflowStocks
from imagematerials.factory import ModelFactory, Sector
from imagematerials.preprocessing_test import get_preprocessing_data
from imagematerials.fossil_fuels.preprocessing.ffconstants import (path_base,STANDARD_SCEN_EXTERNAL_DATA)
from imagematerials.fossil_fuels.preprocessing.main_test import get_preprocessing_data_extraction
from imagematerials.fossil_fuels.preprocessing.main_test import get_preprocessing_data_processing
from imagematerials.fossil_fuels.preprocessing.main_test import get_preprocessing_data_transport
from imagematerials.fossil_fuels.preprocessing.main_test import get_preprocessing_data_pipelines
from imagematerials.fossil_fuels.preprocessing.main_test import get_preprocessing_data_volume
from imagematerials.fossil_fuels.preprocessing.ffconstants import REGIONS_TIMER

from imagematerials.util import reindex_material

# %%
YEAR_START = 1971   # start year of the simulation period
YEAR_END = 2100     # end year of the calculations
YEAR_OUT = 2100     # year of output generation = last year of reporting
year_end = 2100     # end year of the calculations
year_out = 2100
year_start = 1971 

#define path base or current path?
#Select scenario here and also in "ffconstants.py" as well 
circular_economy_config = None
climate_policy_config = "SSP2_baseline" #SSP2_baseline and SSP2(default used by FUMA)
scenario = "SSP2_baseline" 
base_dir =  Path(path_base,"data", "raw")

# %%
scenario_list = {"SSP2":("SSP2_baseline", None),
                # add your scenarios
                 }

time_start = 1971
complete_timeline = prism.Timeline(time_start, YEAR_END, 1)
simulation_timeline = prism.Timeline(YEAR_START, YEAR_END, 1)

materials = [
    'aluminium', 'brick',  'cobalt', 'concrete','cement', 'copper', 'glass',        
    'lead', 'lithium', 'manganese', 'neodymium', 'nickel', 'plastics',
    'rubber', 'steel', 'tantalum', 'titanium', 'wood'
]

# %% [markdown]
# # Run model

# %%
all_output = {}

# add debugging statements
logging.basicConfig(
    level=logging.DEBUG,
    format='%(name)s - %(levelname)s - %(message)s',
    force=True  # Override any existing config
)

for scen_id, (climate_scen, circular_scen) in scenario_list.items():
    climate_policy_scenario_dir = Path(base_dir, "image", climate_scen)
    circular_economy_scenario_dir = None 
    scenario = base_dir /"fossil_fuels"/ STANDARD_SCEN_EXTERNAL_DATA

    # get preprocessing data

    # FOSSIL FUELS
    ff_sector = get_preprocessing_data("fossil_fuels", base_dir,
                                        climate_policy_scenario_dir, 
                                        circular_economy_scenario_dir, cache = False) 
    ff_extr, ff_proc, ff_trp, ff_pipe, ff_vol = (       # change ff_vol
    {sec.name: sec for sec in ff_sector}[k]
    for k in ["ff_extr", "ff_proc", "ff_trp", "ff_pipe", "ff_vol"])# change ff_vol
    
    # #ELECTRICITY
    elc_sector = get_preprocessing_data("electricity", base_dir, climate_policy_scenario_dir, circular_economy_scenario_dir, cache = False)
    elc_gen, elc_grid_lines, elc_grid_add, elc_stor_phs, elc_stor_other = (
    {sec.name: sec for sec in elc_sector}[k]
    for k in ["elc_gen", "elc_grid_lines", "elc_grid_add", "elc_stor_phs", "elc_stor_other"])
    
     # Reindex materials in all sectors to ensure consistency
    for sec in [
    ff_extr, 
    ff_proc,
    ff_trp,
    ff_pipe,
    ff_vol,
    elc_gen,
    elc_grid_lines,
    elc_grid_add,
    elc_stor_phs,
    elc_stor_other,
    ]:
        for key, val in sec.prep_data.items():
            sec.prep_data[key] = reindex_material(val, materials)    

    factory = ModelFactory(
   [ *ff_sector, *elc_sector], complete_timeline
    ).add(GenericStocks, ["ff_extr","ff_proc","ff_trp","ff_pipe", "ff_vol", #change ff_vol
                         "elc_gen", "elc_grid_lines", "elc_grid_add", "elc_stor_phs"
                          ]
    ).add(SharesInflowStocks, ["elc_stor_other"]
    ).add(MaterialIntensities, ["ff_extr","ff_proc","ff_trp","ff_pipe", "ff_vol", #change ff_vol
                         "elc_gen", "elc_grid_lines", "elc_grid_add", "elc_stor_phs"
                          ])
    # ).add(GenericMaterials, ["ff_trp"])
    model = factory.finish()

    model.simulate(simulation_timeline)
    # save relevant outputs only to reduce memory usage
    all_output[scen_id] = model
    
    print(f"Finished {scen_id}")

# %%
list(model.ff_extr)

# %%
model.ff_extr["stock_by_cohort_materials"]

# %%
model.ff_pipe["stock_by_cohort"]
color = "#80AB6E"

# %%
from imagematerials.concepts import create_fossil_fuel_graph

kgraph_fossil_fuel = create_fossil_fuel_graph()
stocks_ff_extr = model.ff_extr["stock_by_cohort"]

test = kgraph_fossil_fuel.aggregate_sum(stocks_ff_extr, ["Coal", "Oil", "Gas"])

# %%
stocks_ff_extr = model.ff_extr["stock_by_cohort"]
stocks_ff_proc = model.ff_proc["stock_by_cohort"]
all_sectors_stocks = xr.concat([stocks_ff_extr, stocks_ff_proc], dim="Type")
all_sectors_stocks
test = kgraph_fossil_fuel.aggregate_sum(all_sectors_stocks, ["Coal", "Oil", "Gas"])
test

# %%
stocks_ff_extr

# %%
test

# %%
# all_output["SSP2_baseline"].ff_extr.keys()
# all_output["SSP2"].ff_extr.keys()

# %% [markdown]
# # Plots

# %% [markdown]
# ## Plot materials

# %% [markdown]
# ### s: extraction

# %%
# All output to array to see dimensions and sometimes to plot because the key returned by the model is an xarray dataset.
# all_output["SSP2_baseline"].ff_extr["outflow_by_cohort_materials"].to_array()
all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"]
all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"]
# all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"]
# all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"]
# all_output["SSP2_baseline"].ff_extr["outflow_by_cohort_materials"].to_array().sel(Region= "CAN",material = "steel").sum(dim = "Type").plot()
# all_output["SSP2_baseline"].ff_extr["outflow_by_cohort_materials"].to_array().sel(Region= "USA",material = "aluminium").sum(dim = "Type").plot()
# all_output["SSP2_baseline"].ff_extr["inflow_materials"].to_array().sel(Region=1,material = "steel").sum(dim = "Type").plot()

# %%
# you can also save the steps in between in a variable to avoid repeating the same things, for example:
# save the model output of a specific scenario
# SSP2_FUMA_scenario = all_output["SSP2"]
SSP2_test_scenario = all_output["SSP2"]

# SSP2_baseline_scenario = all_output["SSP2_baseline"]

# coal_extraction_types = ["Coal Opencast", "Coal Underground"]
# coal_processing_types = ["Coal Preparation"]
# coal_transport_types = ["Coal Inland Ship", "Coal Ocean Ship", "Coal Rail", "Coal Truck"]

# gas_extraction_types = ["Gas Offshore", "Gas Onshore"]
# gas_processing_types = ["Gas Processing"]
# gas_transport_types = ["Gas Inland Ship", "Gas Ocean Ship", "Gas Rail", "Gas Truck"]
# gas_pipeline_types = ["Gas Distribution Pipeline", "Gas Transmission Pipeline"] 

# oil_extraction_types = ["Oil Offshore", "Oil Onshore"]
# oil_transport_types = ["Oil Inland Ship", "Oil Ocean Ship", "Oil Rail", "Oil Truck"]
# oil_pipeline_types = ["Oil Onshore Crude Pipeline", "Oil Onshore Product Pipeline", "Oil Offshore Crude Pipeline", "Oil Offshore Product Pipeline"] 
# oil_processing_types = ["Oil Refinery", "Oil Storage"]

coal_extraction_types = ["Coal Opencast", "Coal Underground"]
coal_processing_types = ["Coal Preparation"]
coal_transport_types = ["Coal Inland Ship", "Coal Ocean Ship", "Coal Rail", "Coal Truck"]

gas_extraction_types = ["Gas Offshore", "Gas Onshore"]

gas_transport_types = ["Gas Inland Ship", "Gas Ocean Ship", "Gas Rail", "Gas Truck"]
gas_pipeline_types = ["Gas Distribution Pipeline", "Gas Transmission Pipeline"] 

oil_extraction_types = ["Oil Offshore", "Oil Onshore"]
oil_transport_types = ["Oil Inland Ship", "Oil Ocean Ship", "Oil Rail", "Oil Truck"]
oil_pipeline_types = ["Oil Onshore Crude Pipeline", "Oil Onshore Product Pipeline", "Oil Offshore Crude Pipeline", "Oil Offshore Product Pipeline"] 
oil_processing_types = ["Oil Refinery"]

volume_processing_types = ["Gas Processing", "Oil Storage"]

# save a certain variable
# gen_inflow_global = model_scenario_x.elc_gen["inflow"].to_array().sum(["Region"])

# #To change a unit do this:
# var = model_scenario_x.elc_gen["inflow_materials"].to_array().pint.to("megaton")

# # If you automatically want to have the correct unit printed in a figure you can do:
# unit = "megaton"
# var = model_scenario_x.elc_gen["inflow_materials"].to_array().pint.to(unit)

# fig, ax = plt.subplots(figsize=(8,6))

# plt.ylabel(f"material inflow ({unit})", fontsize=14)

# %%
#the key for the stock by cohort materials is already in xarray format, so we can directly select the material and region and plot it.

#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
trp.plot(label="Transportation")

vol = all_output["SSP2"].ff_vol["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
vol.plot(label="Volume")

# Sum of all
total = extr + pipe + proc + trp + vol
total.plot(label="Total", linewidth=2, linestyle="--")
plt.title("Steel Stock by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0, 1800) 

plt.legend()

print(total.sel(Time=[2019, 2050]).to_series())

# %%
#the key for the stock by cohort materials is already in xarray format, so we can directly select the material and region and plot it.

#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
trp.plot(label="Transportation")
 

# Sum of all
total = extr + pipe + proc + trp + vol
total.plot(label="Total", linewidth=2, linestyle="--")
plt.title("Steel Stock by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0, 1600) 

plt.legend()

print(total.sel(Time=[2019, 2050]).to_series())

# %%
#the key for the stock by cohort materials is already in xarray format, so we can directly select the material and region and plot it.

#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
extr.plot(label="Extraction")

pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
proc.plot(label="Processing")

trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"].sel(material="steel").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
trp.plot(label="Transportation")



# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")
plt.title("Steel Stock by Cohort Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0, 1600) 

plt.legend()

print(total.sel(Time=[2019, 2050]).to_series())

# %%
# plot for copper in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
extr.plot(label="Extraction")
pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
pipe.plot(label="Pipeline")
proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
proc.plot(label="Processing")
trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
trp.plot(label="Transport")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Copper Stock by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0, 1.3) 

print(total.sel(Time=[2019, 2050]).to_series())

# %%
# plot for copper in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
extr.plot(label="Extraction")
pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
pipe.plot(label="Pipeline")
proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
proc.plot(label="Processing")
trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"].sel(material = "copper").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
trp.plot(label="Transport")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Copper Stock by Cohort Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0, 1.2) 

print(total.sel(Time=[2019, 2050]).to_series())

# %%
# plot for aluminium in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
extr.plot(label="Extraction")
pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
pipe.plot(label="Pipeline")
proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
proc.plot(label="Processing")
trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Stock by Cohort Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.grid(True)
plt.legend()
plt.ylim(0, 16) 

print(total.sel(Time=[2019, 2050]).to_series())

# %%
# plot for aluminium in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
extr.plot(label="Extraction")
pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
pipe.plot(label="Pipeline")
proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
proc.plot(label="Processing")
trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Stock by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.grid(True)
plt.legend()
plt.ylim(0, 16) 

print(total.sel(Time=[2019, 2050]).to_series())

# %%
# plot for aluminium in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
extr.plot(label="Extraction")
pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
pipe.plot(label="Pipeline")
proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
proc.plot(label="Processing")
trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material = "aluminium").sel(Time=slice(1990, 2050)).sum(dim = "Type").sum(dim = "Region").pint.to("megaton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Stock by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.grid(True)
plt.legend()
plt.ylim(0, 16) 

print(total.sel(Time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
# extr = all_output["SSP2_baseline"].ff_extr["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1980, 2100)).sum(dim="Type").sum(dim="Region")
# extr.plot(label="Extraction")

# pipe = all_output["SSP2_baseline"].ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1980, 2100)).sum(dim="Type").sum(dim="Region")
# pipe.plot(label="Pipeline")

# proc = all_output["SSP2_baseline"].ff_proc["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1980, 2100)).sum(dim="Type").sum(dim="Region")
# proc.plot(label="Processing")

# trp = all_output["SSP2_baseline"].ff_trp["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1980, 2100)).sum(dim="Type").sum(dim="Region")
# trp.plot(label="Transportation")

extr = all_output["SSP2_baseline"].ff_extr["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
extr.plot(label="Extraction")

pipe = all_output["SSP2_baseline"].ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2_baseline"].ff_proc["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
proc.plot(label="Processing")

trp = all_output["SSP2_baseline"].ff_trp["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Steel Outflow by Cohort Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Outflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())
# print(extr.dims)

# %%
extr = all_output["SSP2"].ff_extr["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["outflow_by_cohort_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Steel Outflow by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Outflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())
# print(extr.dims)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2_baseline"].ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2_baseline"].ff_proc["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2_baseline"].ff_trp["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Copper Outflow by Cohort Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Outflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["outflow_by_cohort_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Copper Outflow by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Outflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2_baseline"].ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2_baseline"].ff_proc["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2_baseline"].ff_trp["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Outflow by Cohort Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Outflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())

# plt.legend()

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["outflow_by_cohort_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Outflow by Cohort Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Outflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
extr.plot(label="Extraction")

pipe = all_output["SSP2_baseline"].ff_pipe["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2_baseline"].ff_proc["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
proc.plot(label="Processing")

trp = all_output["SSP2_baseline"].ff_trp["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Steel Inflow Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Inflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())
# plt.legend()

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["inflow_materials"].to_array().sel(material="steel").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Steel Inflow Materials - Fossil Fuels - SSP2FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Inflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())
# plt.legend()

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2_baseline"].ff_pipe["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2_baseline"].ff_proc["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2_baseline"].ff_trp["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")


plt.title("Copper Inflow Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Inflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())
# plt.legend()

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["inflow_materials"].to_array().sel(material="copper").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")


plt.title("Copper Inflow Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Inflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)

print(total.sel(time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2_baseline"].ff_extr["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2_baseline"].ff_pipe["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2_baseline"].ff_proc["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2_baseline"].ff_trp["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Inflow Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Inflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0,600)

# plt.legend()
print(total.sel(time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
extr = all_output["SSP2"].ff_extr["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
extr.plot(label="Extraction")

pipe = all_output["SSP2"].ff_pipe["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
pipe.plot(label="Pipeline")

proc = all_output["SSP2"].ff_proc["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
proc.plot(label="Processing")

trp = all_output["SSP2"].ff_trp["inflow_materials"].to_array().sel(material="aluminium").sel(time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
trp.plot(label="Transportation")

# Sum of all
total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Inflow Materials - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Inflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0,600)

# plt.legend()
print(total.sel(time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="steel", Type=gas_extraction_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="steel", Type=gas_pipeline_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="steel", Type=gas_processing_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material="steel", Type=gas_transport_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="steel", Type=oil_extraction_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="steel", Type=oil_pipeline_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"] .sel(material="steel", Type=oil_processing_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="steel", Type=oil_transport_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="steel", Type=coal_extraction_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="steel", Type=coal_processing_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="steel", Type=coal_transport_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total  = oil_extr + oil_pipe + oil_proc + oil_trp

print(gas_total.sel(Time=[2019, 2050]).to_series())
print(coal_total.sel(Time=[2019, 2050]).to_series())
print(oil_total.sel(Time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=gas_extraction_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"] .sel(material="copper", Type=gas_pipeline_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=gas_processing_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material="copper", Type=gas_transport_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"] .sel(material="copper", Type=oil_extraction_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="copper", Type=oil_pipeline_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"] .sel(material="copper", Type=oil_processing_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=oil_transport_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=coal_extraction_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=coal_processing_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=coal_transport_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total  = oil_extr + oil_pipe + oil_proc + oil_trp

print(gas_total.sel(Time=[2019, 2050]).to_series())
print(coal_total.sel(Time=[2019, 2050]).to_series())
print(oil_total.sel(Time=[2019, 2050]).to_series())

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_extraction_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"] .sel(material="aluminium", Type=gas_pipeline_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_processing_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_transport_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_extraction_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="aluminium", Type=oil_pipeline_types, Time=[2019, 2050]).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_processing_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_transport_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_extraction_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_processing_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=coal_transport_types, Time=[2019, 2050]) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total  = oil_extr + oil_pipe + oil_proc + oil_trp

print(gas_total.sel(Time=[2019, 2050]).to_series())
print(coal_total.sel(Time=[2019, 2050]).to_series())
print(oil_total.sel(Time=[2019, 2050]).to_series())

total = extr + pipe + proc + trp
total.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Inflow Materials - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "kiloton"
plt.ylabel(f"Inflow ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0,600)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"] .sel(material="aluminium", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"].sel(material="aluminium", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

gas_total.plot(label="Gas", linewidth=2, linestyle="-")
coal_total.plot(label="Coal", linewidth=2, linestyle="-")
oil_total.plot(label="Oil", linewidth=2, linestyle="-")
total_overall.plot(label="Total", linewidth=2, linestyle="--")

# plt.title("Aluminium Stock - Fossil Fuels - SSP2 BL")
# plt.xlabel("Time")
# unit = "megaton"
# plt.ylabel(f"Stock ({unit})", fontsize=14)
# plt.legend()
# plt.grid(True)
# plt.ylim(0,15)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"] .sel(material="aluminium", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="aluminium", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
storage = all_output["SSP2"].ff_oilstorage["stock_by_cohort_materials"].sel(material="aluminium").sel(Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp + storage
total_overall = gas_total + coal_total + oil_total

gas_total.plot(label="Gas", linewidth=2, linestyle="-")
coal_total.plot(label="Coal", linewidth=2, linestyle="-")
oil_total.plot(label="Oil", linewidth=2, linestyle="-")
total_overall.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Aluminium Stock - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0,18)


#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"] .sel(material="aluminium", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"].sel(material="aluminium", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

gas_total.plot(label="Gas", linewidth=2, linestyle="-")
coal_total.plot(label="Coal", linewidth=2, linestyle="-")
oil_total.plot(label="Oil", linewidth=2, linestyle="-")
total_overall.plot(label="Total", linewidth=2, linestyle="--")

unit = "megaton"

# fig, ax = plt.subplots(figsize=(8,6))
# ax.stackplot(
#     dataarray.Time,
#     dataarray,
#     labels=dataarray.Type.values
# # )
# ax.grid(alpha=0.3)
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# plt.legend(loc="upper left", bbox_to_anchor=(1, 1), fontsize=8, ncol=2)
# ax.set_xlabel("Time", fontsize=14)
# ax.set_ylabel(f"Variable ({unit})", fontsize=14)
# ax.set_title("Variable over time (SSP2 baseline)", fontweight="bold")

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"] .sel(material="copper", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"].sel(material="copper", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"] .sel(material="copper", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"].sel(material="copper", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"] .sel(material="copper", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")

# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

gas_total.plot(label="Gas", linewidth=2, linestyle="-")
coal_total.plot(label="Coal", linewidth=2, linestyle="-")
oil_total.plot(label="Oil", linewidth=2, linestyle="-")
total_overall.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Copper Stock - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0,1.2)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"] .sel(material="copper", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"].sel(material="copper", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"] .sel(material="copper", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2"].ff_pipe["stock_by_cohort_materials"].sel(material="copper", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"] .sel(material="copper", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2"].ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2"].ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2"].ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")

# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

gas_total.plot(label="Gas", linewidth=2, linestyle="-")
coal_total.plot(label="Coal", linewidth=2, linestyle="-")
oil_total.plot(label="Oil", linewidth=2, linestyle="-")
total_overall.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Copper Stock - Fossil Fuels - SSP2 FUMA")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0,1.4)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="steel", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"] .sel(material="steel", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="steel", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"].sel(material="steel", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"] .sel(material="steel", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = all_output["SSP2_baseline"].ff_pipe["stock_by_cohort_materials"].sel(material="steel", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"] .sel(material="steel", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="steel", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = all_output["SSP2_baseline"].ff_extr["stock_by_cohort_materials"].sel(material="steel", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = all_output["SSP2_baseline"].ff_proc["stock_by_cohort_materials"].sel(material="steel", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = all_output["SSP2_baseline"].ff_trp["stock_by_cohort_materials"] .sel(material="steel", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

gas_total.plot(label="Gas", linewidth=2, linestyle="-")
coal_total.plot(label="Coal", linewidth=2, linestyle="-")
oil_total.plot(label="Oil", linewidth=2, linestyle="-")
total_overall.plot(label="Total", linewidth=2, linestyle="--")

plt.title("Steel Stock - Fossil Fuels - SSP2 BL")
plt.xlabel("Time")
unit = "megaton"
plt.ylabel(f"Stock ({unit})", fontsize=14)
plt.legend()
plt.grid(True)
plt.ylim(0,1600)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material="steel", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"] .sel(material="steel", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material="steel", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"].sel(material="steel", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"] .sel(material="steel", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"].sel(material="steel", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"] .sel(material="steel", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material="steel", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material="steel", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material="steel", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material="steel", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")

# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

unit = "megaton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.Time.values,
    coal_total.values,   # bottom
    oil_total.values,    # middle
    gas_total.values,    # top
    labels=["Coal", "Oil", "Gas"],
    colors=["#606060", "#F07721", "#0692C9"]
)

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel(f"Stock ({unit})", fontsize=14)
ax.set_title("Steel Stock - SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
# dataarray_2 = fossil_fuel_graph.aggregate_sum(dataarray, output_coords=["Coal", "Oil", "Gas"], dim="Type")

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"] .sel(material="copper", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"].sel(material="copper", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"] .sel(material="copper", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"].sel(material="copper", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"] .sel(material="copper", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material="copper", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material="copper", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material="copper", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")

# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

unit = "megaton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.Time.values,
    coal_total.values,   # bottom
    oil_total.values,    # middle
    gas_total.values,    # top
    labels=["Coal", "Oil", "Gas"],
    colors=["#606060", "#F07721", "#0692C9"]
)

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel(f"Stock ({unit})", fontsize=14)
ax.set_title("Copper Stock - SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_extraction_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"] .sel(material="aluminium", Type=gas_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_processing_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"].sel(material="aluminium", Type=gas_transport_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"].sel(material="aluminium", Type=oil_pipeline_types, Time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=oil_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_extraction_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material="aluminium", Type=coal_processing_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material="aluminium", Type=coal_transport_types, Time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

unit = "megaton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.Time.values,
    coal_total.values,   # bottom
    oil_total.values,    # middle
    gas_total.values,    # top
    labels=["Coal", "Oil", "Gas"],
    colors=["#606060", "#F07721", "#0692C9"]
)

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel(f"Stock ({unit})", fontsize=14)
ax.set_title("Aluminium Stock - SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_test_scenario.ff_extr["inflow_materials"].to_array().sel(material="aluminium", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_pipe = SSP2_test_scenario.ff_pipe["inflow_materials"].to_array().sel(material="aluminium", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
vol = SSP2_test_scenario.ff_vol["inflow_materials"].to_array().sel(material="aluminium", Type=volume_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_trp = SSP2_test_scenario.ff_trp["inflow_materials"].to_array().sel(material="aluminium", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_extr = SSP2_test_scenario.ff_extr["inflow_materials"] .to_array().sel(material="aluminium", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_pipe = SSP2_test_scenario.ff_pipe["inflow_materials"].to_array().sel(material="aluminium", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_proc = SSP2_test_scenario.ff_proc["inflow_materials"] .to_array().sel(material="aluminium", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_trp = SSP2_test_scenario.ff_trp["inflow_materials"] .to_array().sel(material="aluminium", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_extr = SSP2_test_scenario.ff_extr["inflow_materials"].to_array().sel(material="aluminium", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_proc = SSP2_test_scenario.ff_proc["inflow_materials"].to_array().sel(material="aluminium", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_trp = SSP2_test_scenario.ff_trp["inflow_materials"].to_array().sel(material="aluminium", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")


# Sum of all
gas_total = gas_extr + gas_pipe  + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp 
vol_total = vol
total_overall = gas_total + coal_total + oil_total + vol_total

gas_extr_out = SSP2_test_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_pipe_out = SSP2_test_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
vol_out = SSP2_test_scenario.ff_vol["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=volume_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_trp_out = SSP2_test_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_extr_out = SSP2_test_scenario.ff_extr["outflow_by_cohort_materials"] .to_array().sel(material="aluminium", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_pipe_out = SSP2_test_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_proc_out = SSP2_test_scenario.ff_proc["outflow_by_cohort_materials"] .to_array().sel(material="aluminium", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_trp_out = SSP2_test_scenario.ff_trp["outflow_by_cohort_materials"] .to_array().sel(material="aluminium", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_extr_out = SSP2_test_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_proc_out = SSP2_test_scenario.ff_proc["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_trp_out = SSP2_test_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="aluminium", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
# Sum of all
gas_total_out = gas_extr_out + gas_pipe_out + gas_trp_out
coal_total_out = coal_extr_out + coal_proc_out + coal_trp_out
oil_total_out = oil_extr_out + oil_pipe_out + oil_proc_out+ oil_trp_out 
vol_total_out = vol_out
total_overall_out = gas_total_out + coal_total_out + oil_total_out + vol_total_out

print(vol_total)
print(vol_total_out)

print(total_overall.sel(time=[2019, 2050]).to_series())
print(total_overall_out.sel(time=[2019, 2050]).to_series())

unit = "kiloton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.time.values,
    coal_total.values,   # bottom
    gas_total.values, 
    oil_total.values,    # middle
    vol_total.values,    # top
    labels=["Coal", "Gas", "Oil", "Volume"],
    colors=["#606060","#0692C9", "#F07721", "#A0A0A0"]
)

ax.stackplot(
    gas_total_out.time.values,
    -coal_total_out.values, 
    -gas_total_out.values,  # bottom
    -oil_total_out.values, 
    -vol_total_out.values,    # top
    # labels=["Coal", "Oil", "Gas"],
    colors=["#ADADAD",  "#25BDF8", "#F6AD79", "#A0A0A0" ]
)

ax.set_xlabel("time", fontsize=14)
ax.set_ylabel(f"Inflow & Outflow ({unit})", fontsize=14)
ax.set_title("Aluminium Inflow & Outflow- SSP2 Unit Test", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="steel", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="steel", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"].to_array().sel(material="steel", Type=gas_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="steel", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"] .to_array().sel(material="steel", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="steel", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"] .to_array().sel(material="steel", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"] .to_array().sel(material="steel", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="steel", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"].to_array().sel(material="steel", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="steel", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

gas_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=gas_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"] .to_array().sel(material="steel", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"] .to_array().sel(material="steel", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"] .to_array().sel(material="steel", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total_out = gas_extr_out + gas_pipe_out + gas_proc_out + gas_trp_out
coal_total_out = coal_extr_out + coal_proc_out + coal_trp_out
oil_total_out = oil_extr_out + oil_pipe_out + oil_proc_out+ oil_trp_out
total_overall_out = gas_total_out + coal_total_out + oil_total_out

unit = "megaton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.time.values,
    coal_total.values,   # bottom
    gas_total.values, 
    oil_total.values,    # middle
    labels=["Coal", "Gas", "Oil"],
    colors=["#606060","#0692C9", "#F07721"]
)

ax.stackplot(
    gas_total_out.time.values,
    -coal_total_out.values, 
    -gas_total_out.values,  # bottom
    -oil_total_out.values,    # middle
    # labels=["Coal", "Oil", "Gas"],
    colors=["#ADADAD",  "#25BDF8", "#F6AD79"]
)

ax.set_xlabel("time", fontsize=14)
ax.set_ylabel(f"Inflow & Outflow ({unit})", fontsize=14)
ax.set_title("Steel Inflow & Outflow- SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="copper", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="copper", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"].to_array().sel(material="copper", Type=gas_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="copper", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"] .to_array().sel(material="copper", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="copper", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"] .to_array().sel(material="copper", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"] .to_array().sel(material="copper", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="copper", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"].to_array().sel(material="copper", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="copper", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")


# Sum of all
gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

gas_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=gas_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"] .to_array().sel(material="copper", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"] .to_array().sel(material="copper", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"] .to_array().sel(material="copper", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")


# Sum of all
gas_total_out = gas_extr_out + gas_pipe_out + gas_proc_out + gas_trp_out
coal_total_out = coal_extr_out + coal_proc_out + coal_trp_out
oil_total_out = oil_extr_out + oil_pipe_out + oil_proc_out+ oil_trp_out
total_overall_out = gas_total_out + coal_total_out + oil_total_out

unit = "kiloton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.time.values,
    coal_total.values,   # bottom
    gas_total.values, 
    oil_total.values,    # middle
    labels=["Coal", "Gas", "Oil"],
    colors=["#606060","#0692C9", "#F07721"]
)

ax.stackplot(
    gas_total_out.time.values,
    -coal_total_out.values, 
    -gas_total_out.values,  # bottom
    -oil_total_out.values,    # middle
    # labels=["Coal", "Oil", "Gas"],
    colors=["#ADADAD",  "#25BDF8", "#F6AD79"]
)

ax.set_xlabel("time", fontsize=14)
ax.set_ylabel(f"Inflow & Outflow ({unit})", fontsize=14)
ax.set_title("Copper Inflow & Outflow- SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
# SSP2test = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="copper", time=slice(1990, 2050)).sum(dim="Region").pint.to("kiloton")
# # SSP2categorytest= fossil_fuel_graph.aggregate_coal_extraction_types = ["Coal Opencast", "Coal Underground"]

material = "copper"
unit = "megaton"
firstplotyear = 1990
lastplotyear = 2050

#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material=material, Type=gas_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
gas_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"] .sel(material=material, Type=gas_pipeline_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
gas_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material=material, Type=gas_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
gas_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"].sel(material=material, Type=gas_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"] .sel(material=material, Type=oil_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"].sel(material=material, Type=oil_pipeline_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"] .sel(material=material, Type=oil_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material=material, Type=oil_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material=material, Type=coal_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material=material, Type=coal_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material=material, Type=coal_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)

gas_total = gas_extr + gas_pipe + gas_proc + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
total_overall = gas_total + coal_total + oil_total

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.Time.values,
    coal_total.values,   # bottom
    oil_total.values,    # middle
    gas_total.values,    # top
    labels=["Coal", "Oil", "Gas"],
    colors=["#606060", "#F07721", "#0692C9"]
)

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel(f"Stock ({unit})", fontsize=14)
ax.set_title("Copper Stock- SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="steel", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="steel", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
vol = SSP2_FUMA_scenario.ff_vol["inflow_materials"].to_array().sel(material="steel", Type=volume_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="steel", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"] .to_array().sel(material="steel", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="steel", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"] .to_array().sel(material="steel", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"] .to_array().sel(material="steel", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="steel", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"].to_array().sel(material="steel", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="steel", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")


# Sum of all
gas_total = gas_extr + gas_pipe  + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp 
vol_total = vol
total_overall = gas_total + coal_total + oil_total + vol_total

gas_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
vol_out = SSP2_FUMA_scenario.ff_vol["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=volume_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
gas_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"] .to_array().sel(material="steel", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"] .to_array().sel(material="steel", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
oil_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"] .to_array().sel(material="steel", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")
coal_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="steel", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("megaton")

# Sum of all
gas_total_out = gas_extr_out + gas_pipe_out + gas_trp_out
coal_total_out = coal_extr_out + coal_proc_out + coal_trp_out
oil_total_out = oil_extr_out + oil_pipe_out + oil_proc_out+ oil_trp_out 
vol_total_out = vol_out
total_overall_out = gas_total_out + coal_total_out + oil_total_out + vol_total_out

# print(vol_total)
# print(vol_total_out)

print(total_overall.sel(time=[2019, 2050]).to_series())
print(total_overall_out.sel(time=[2019, 2050]).to_series())

unit = "megaton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.time.values,
    coal_total.values,   # bottom
    gas_total.values, 
    oil_total.values,    # middle
    vol_total.values,    # top
    labels=["Coal", "Gas", "Oil", "Volume"],
    colors=["#606060","#0692C9", "#F07721", "#A0A0A0"]
)

ax.stackplot(
    gas_total_out.time.values,
    -coal_total_out.values, 
    -gas_total_out.values,  # bottom
    -oil_total_out.values, 
    -vol_total_out.values,    # top
    # labels=["Coal", "Oil", "Gas"],
    colors=["#ADADAD",  "#25BDF8", "#F6AD79", "#A0A0A0" ]
)

ax.set_xlabel("time", fontsize=14)
ax.set_ylabel(f"Inflow & Outflow ({unit})", fontsize=14)
ax.set_title("Steel Inflow & Outflow- SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="copper", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="copper", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
vol = SSP2_FUMA_scenario.ff_vol["inflow_materials"].to_array().sel(material="copper", Type=volume_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="copper", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"] .to_array().sel(material="copper", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_pipe = SSP2_FUMA_scenario.ff_pipe["inflow_materials"].to_array().sel(material="copper", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"] .to_array().sel(material="copper", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"] .to_array().sel(material="copper", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_extr = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="copper", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_proc = SSP2_FUMA_scenario.ff_proc["inflow_materials"].to_array().sel(material="copper", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_trp = SSP2_FUMA_scenario.ff_trp["inflow_materials"].to_array().sel(material="copper", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")


# Sum of all
gas_total = gas_extr + gas_pipe  + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp 
vol_total = vol
total_overall = gas_total + coal_total + oil_total + vol_total

gas_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=gas_extraction_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=gas_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
vol_out = SSP2_FUMA_scenario.ff_vol["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=volume_processing_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
gas_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=gas_transport_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"] .to_array().sel(material="copper", Type=oil_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_pipe_out = SSP2_FUMA_scenario.ff_pipe["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=oil_pipeline_types, time=slice(1990, 2050)).sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"] .to_array().sel(material="copper", Type=oil_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
oil_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"] .to_array().sel(material="copper", Type=oil_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_extr_out = SSP2_FUMA_scenario.ff_extr["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=coal_extraction_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_proc_out = SSP2_FUMA_scenario.ff_proc["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=coal_processing_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")
coal_trp_out = SSP2_FUMA_scenario.ff_trp["outflow_by_cohort_materials"].to_array().sel(material="copper", Type=coal_transport_types, time=slice(1990, 2050)) .sum(dim="Type").sum(dim="Region").pint.to("kiloton")

# Sum of all
gas_total_out = gas_extr_out + gas_pipe_out + gas_trp_out
coal_total_out = coal_extr_out + coal_proc_out + coal_trp_out
oil_total_out = oil_extr_out + oil_pipe_out + oil_proc_out+ oil_trp_out 
vol_total_out = vol_out
total_overall_out = gas_total_out + coal_total_out + oil_total_out + vol_total_out

print(vol_total)
print(vol_total_out)

print(total_overall.sel(time=[2019, 2050]).to_series())
print(total_overall_out.sel(time=[2019, 2050]).to_series())

unit = "kiloton"

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.time.values,
    coal_total.values,   # bottom
    gas_total.values, 
    oil_total.values,    # middle
    vol_total.values,    # top
    labels=["Coal", "Gas", "Oil", "Volume"],
    colors=["#606060","#0692C9", "#F07721", "#A0A0A0"]
)

ax.stackplot(
    gas_total_out.time.values,
    -coal_total_out.values, 
    -gas_total_out.values,  # bottom
    -oil_total_out.values, 
    -vol_total_out.values,    # top
    # labels=["Coal", "Oil", "Gas"],
    colors=["#ADADAD",  "#25BDF8", "#F6AD79", "#A0A0A0" ]
)

ax.set_xlabel("time", fontsize=14)
ax.set_ylabel(f"Inflow & Outflow ({unit})", fontsize=14)
ax.set_title("Copper Inflow & Outflow- SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

# %%
# SSP2test = SSP2_FUMA_scenario.ff_extr["inflow_materials"].to_array().sel(material="copper", time=slice(1990, 2050)).sum(dim="Region").pint.to("kiloton")
# # SSP2categorytest= fossil_fuel_graph.aggregate_coal_extraction_types = ["Coal Opencast", "Coal Underground"]

material = "steel"
unit = "megaton"
firstplotyear = 1990
lastplotyear = 2050

#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material=material, Type=gas_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
gas_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"] .sel(material=material, Type=gas_pipeline_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
vol = SSP2_FUMA_scenario.ff_vol["stock_by_cohort_materials"].sel(material=material, Type=volume_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
gas_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"].sel(material=material, Type=gas_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"] .sel(material=material, Type=oil_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"].sel(material=material, Type=oil_pipeline_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"] .sel(material=material, Type=oil_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material=material, Type=oil_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material=material, Type=coal_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material=material, Type=coal_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material=material, Type=coal_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)

gas_total = gas_extr + gas_pipe + gas_trp
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp
vol_total = vol
total_overall = gas_total + coal_total + oil_total + vol_total

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.Time.values,
    coal_total.values,   # bottom
    oil_total.values,    # middle
    gas_total.values,    # top
    vol_total.values,
    labels=["Coal", "Oil", "Gas", "Volume"],
    colors=["#606060", "#F07721", "#0692C9", "#A0A0A0"]
)

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel(f"Stock ({unit})", fontsize=14)
ax.set_title(f"{material} Stock- SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

print(total_overall.sel(Time=[2019, 2050]).to_series())

print(vol_total.sel(Time=[2019, 2050]).to_series())

# %%
# Test idea for final figures 

material = "steel"
unit = "megaton"
firstplotyear = 1990
lastplotyear = 2100

#plot for steel in all regions and types for each sector plotted on the same graph to compare the sectors.
gas_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material=material, Type=gas_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
gas_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"] .sel(material=material, Type=gas_pipeline_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_storage = SSP2_FUMA_scenario.ff_vol["stock_by_cohort_materials"].sel(material=material, Type="Oil Storage", Time=slice(firstplotyear, lastplotyear)).sum(dim="Region").pint.to(unit)
gas_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"].sel(material=material, Type=gas_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"] .sel(material=material, Type=oil_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_pipe = SSP2_FUMA_scenario.ff_pipe["stock_by_cohort_materials"].sel(material=material, Type=oil_pipeline_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"] .sel(material=material, Type=oil_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
oil_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material=material, Type=oil_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_extr = SSP2_FUMA_scenario.ff_extr["stock_by_cohort_materials"].sel(material=material, Type=coal_extraction_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_proc = SSP2_FUMA_scenario.ff_proc["stock_by_cohort_materials"].sel(material=material, Type=coal_processing_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
coal_trp = SSP2_FUMA_scenario.ff_trp["stock_by_cohort_materials"] .sel(material=material, Type=coal_transport_types, Time=slice(firstplotyear, lastplotyear)).sum(dim="Type").sum(dim="Region").pint.to(unit)
gas_processing = SSP2_FUMA_scenario.ff_vol["stock_by_cohort_materials"].sel(material=material, Type="Gas Processing", Time=slice(firstplotyear, lastplotyear)).sum(dim="Region").pint.to(unit)


gas_total = gas_extr + gas_pipe + gas_trp + gas_processing
coal_total = coal_extr + coal_proc + coal_trp
oil_total = oil_extr + oil_pipe + oil_proc + oil_trp + oil_storage
total_overall = gas_total + coal_total + oil_total

fig, ax = plt.subplots(figsize=(10,6))

ax.stackplot(
    gas_total.Time.values,
    coal_total.values,   # bottom
    oil_total.values,    # middle
    gas_total.values,    # top
    labels=["Coal", "Oil", "Gas"],
    colors=["#606060", "#F07721", "#0692C9"]
)

ax.set_xlabel("Time", fontsize=14)
ax.set_ylabel(f"Stock ({unit})", fontsize=14)
ax.set_title(f"{material} Stock- SSP2 FUMA", fontweight="bold")

ax.legend(loc="upper left")
ax.grid(alpha=0.3)

print(total_overall.sel(Time=[2019, 2050]).to_series())

print(vol_total.sel(Time=[2019, 2050]).to_series())

#line charts comparing total stock, inflow, outflow for each material
# Line chart comparing scenarios for total stock, inflow, outflow for each material/each fuel type 
# run and create totals for each materials and then make a figure with those totals compared?
