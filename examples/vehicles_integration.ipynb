# %%
import warnings

import prism
from prism import Q_

from imagematerials.vehicles.timermodel import TIMERMaterials

# %%
# Define the complete timeline, including historic tail
time_start = Q_(1960, 'year')
time_end = Q_(2060, 'year')
simulation_start = Q_(1970, 'year')
step = Q_(1, 'year')
complete_timeline = prism.Timeline(time_start, time_end, step)
simulation_timeline = prism.Timeline(simulation_start, time_end, step)

# %%
timer_vehicle_model = TIMERMaterials(complete_timeline) # TODO: fix signature

timer_vehicle_model.simulate(simulation_timeline)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 timer_vehicle_model = TIMERMaterials(complete_timeline) # TODO: fix signature
#       3 timer_vehicle_model.simulate(simulation_timeline)
#
# File <string>:3, in __init__(self, time)
#
# File c:\Users\5982758\AppData\Local\anaconda3\envs\materials_dev_26\Lib\site-packages\prism\_interface.py:273, in interface.<locals>.post_init(self, timeline)
#     272 def post_init(self, timeline: Timeline):
# --> 273     _update_model(
#     274         model=self,
#     275         field_annotations=field_annotations,
#     276         dim_to_attribute_map=dim_to_attribute_map,
#     277         unit_to_attribute_map=unit_to_attribute_map,
#     278         timeline=timeline
#     279     )
#
# File c:\Users\5982758\AppData\Local\anaconda3\envs\materials_dev_26\Lib\site-packages\prism\_interface.py:256, in _update_model(model, field_annotations, dim_to_attribute_map, unit_to_attribute_map, timeline)
#     254     setattr(model, annotation.name, value)
#     255 if hasattr(model, "init_submodels"):
# --> 256     model.init_submodels(timeline)
#
# File ~\repos\image-materials\imagematerials\vehicles\timermodel.py:38, in TIMERMaterials.init_submodels(self, timeline)
#      36 def init_submodels(self, timeline: prism.Timeline):
#      37     vehicles = VehicleStocks(timeline)
# ---> 38     vehicles.compute_initial_values(timeline)
#      40     # TODO: find a better way to do this
#      41     # Extract dimensions from the VehicleStocks submodel if not already set
#      42     if not hasattr(self, 'Region') or self.Region is None:
#
# File ~\repos\image-materials\imagematerials\vehicles\stocks_prism.py:106, in VehicleStocks.compute_initial_values(self, time)
#      97 """Initialize the stocks TimeVariable with zeros.
#      98
#      99 Parameters
#    (...)    102     The simulation timeline
#     103 """
#     104 # Load preprocessing data first
#     105 # TODO: make this flexible with scenarios etc set in settings/constants file
# --> 106 vehicle_preprocessing = get_preprocessing_data(
#     107     "vehicles",
#     108     base_directory,
#     109     climate_policy_scenario_dir=base_directory / "image" / "SSP2_baseline",
#     110     circular_economy_scenario_dirs=None,
#     111     integration_preprocessing = True
#     112 )
#     114 # Extract dimensions from preprocessing data if not already set
#     115 if not hasattr(self, 'Region') or self.Region is None:
#
# File ~\repos\image-materials\imagematerials\preprocessing.py:207, in get_preprocessing_data(sector, base_dir, climate_policy_scenario_dir, circular_economy_scenario_dirs, scenario_name, cache, standard_scenario, year_start, year_end, year_out, integration_preprocessing)
#     204     prep_data = import_from_netcdf(cache)
#     206 if sector == "vehicles":
# --> 207     return _get_vehicles_sector(prep_data)
#     208 elif sector == "buildings":
#     209     return _get_buildings_sector(prep_data)
#
# File ~\repos\image-materials\imagematerials\preprocessing.py:74, in _get_vehicles_sector(prep_data)
#      73 def _get_vehicles_sector(prep_data):
# ---> 74     output_coords_type = list(prep_data["stocks"].Type.values)
#      75     knowledge_graph = prep_data["knowledge_graph"]
#      76     new_prep_data = rebroadcast_prep_data(prep_data, knowledge_graph, dim="Type",
#      77                                           output_coords=output_coords_type)
#
# KeyError: 'stocks'

# %%
# Verify dimensions are set
print(f"Regions: {len(timer_vehicle_model.Region)} - {timer_vehicle_model.Region[:3]}...")
print(f"Types: {len(timer_vehicle_model.Type)} - {timer_vehicle_model.Type[:3]}...")
print(f"Time: {len(timer_vehicle_model.Time)} time steps")
# Out:
# Regions: 26 - [np.str_('CAN'), np.str_('USA'), np.str_('MEX')]...
# Types: 47 - [np.str_('Bikes'), np.str_('Freight Planes'), np.str_('Freight Trains')]...
# Time: 294 time steps
